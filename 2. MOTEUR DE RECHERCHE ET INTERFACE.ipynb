# %%
# On importe les librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ---
# # 2. MOTEUR DE RECHERCHE ET INTERFACE
# ---

# %% [markdown]
# ---
# ## 3.1. Recherche par titre
# ---

# %%
import RECHERCHE_A_PARTIR_DE_TITRE as mp #on importe le module
title=input("Entrez le titre d’un film ou d’une série svp: \n ") #on demande à l'utilisateur son critère de recherche
sortie1= mp.title_search(title) 
print(sortie1) #on affiche les résultats
# Out:
# C:\Users\Camil\anaconda3\PYTHON\lib\site-packages\IPython\core\interactiveshell.py:3357: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Entrez le titre d’un film ou d’une série svp:
#   spider-mAN
#             title   plateforme   date_added  \
# 10347  spider-man  Disney plus  May 3, 2021
#
#                                              description  \
# 10347  A young man with spider-like abilities fights ...
#
#                                listed_in  \
# 10347  Action-Adventure, Animation, Kids
#
#                                                     cast  \
# 10347  Christopher Daniel Barnes, Edward Asner, Linda...
#
#                                listed_in  avg_vote
# 10347  Action-Adventure, Animation, Kids       7.3
# None

# %% [markdown]
# ---
# ## 3.2. Recherche par nom d'acteur/actrice
# ---

# %%
import RECHERCHE_A_PARTIR_DU_NOM_ACTEUR as mr #on importe le module
cast=input("Entrez le nom d'un acteur svp: \n ") #on demande à l'utilisateur son critère de recherche
sortie2= mr.Paracteur(cast)
print(sortie2) #on affiche les résultats
# Out:
# Entrez le nom d'un acteur svp:
#   watson
#          type                                           title  \
# 1089  TV Show                                Scaredy Squirrel
# 1095    Movie                                  Saved By Grace
# 1167  TV Show                                   Rich Africans
# 2534    Movie                                Everybody's Game
# 2606    Movie                               Dreaming Out Loud
# 2791    Movie              Contradiction: A Question Of Faith
# 3254    Movie                                  Angela's Ashes
# 3304  TV Show                                  Always Greener
# 3679    Movie                                    Meeting Evil
# 4026    Movie                                          Elodie
# 4130    Movie                                 Nocturnal Agony
# 4345    Movie                                     The Council
# 4609    Movie                                  Winter Warrior
# ...

# %% [markdown]
# ---
# ## 3.3. Recherche par type et genre
# ---

# %%
import RECHERCHE_A_PARTIR_DU_TYPE_GENRE as mk #on importe le module
print("ATTENTION!: \n Conditions à respecter:  \n 1. Pour les Movie ecrivez Film et pour les TV Show - Série !  \n 2. Si le gendre contient 2 mots, ecrivez-le sans espace svp !   \n")
t=input("Entrez le type du contenu : \n") #on demande à l'utilisateur son critère de recherche
g=input("Entrez le genre du contenu : \n") #on demande à l'utilisateur son critère de recherche
sortie3= mk.searchbyTG(t, g)
print(sortie3) #on affiche les résultats
# Out:
# ATTENTION!:
#  Conditions à respecter:
#  1. Pour les Movie ecrivez Film et pour les TV Show - Série !
#  2. Si le gendre contient 2 mots, ecrivez-le sans espace svp !
# Entrez le type du contenu :
#  Film
# Entrez le genre du contenu :
#  Comedy
# Il y a 1821 films qui correspondent à vos attentes sur Amazon Prime, 380 films sur Disney+ et 343 films sur Netflix.
#      show_id   type                                   title       director  \
# 5502   s5503  Movie                Love Of Fate: Amore Fati   Treagen Kier
# 7161   s7162  Movie                              Middletown    Jay Leonard
# 6876   s6877  Movie  The Misadventures of Mistress Maneater  C.J. Julianus
#
#                                                    cast country date_added  \
# 5502  Coke Horner, Sigh Bleu, Aiko Melissa, Nigel Mo...     NaN        NaN
# 7161  Jesse Lawrence, Suzanna Bornn, Jeff Raiano, De...     NaN        NaN
# 6876  Lorrisa Julianus, Mickey O'Sullivan, Shannon B...     NaN        NaN
#
# ...

# %% [markdown]
# ---
# ## 3.4. Suggestion par critère
# ---

# %%
import SUGGESTION_SELON_PREFERENCES as ml #on importe le module
a=input("Entrez le type d’un film ou d’une série : \n") #on demande à l'utilisateur son critère de recherche
b=input("Entrez le genre d’un film ou d’une série : \n") #on demande à l'utilisateur son critère de recherche
c=input("Entrez la note d’un film ou d’une série : \n") #on demande à l'utilisateur son critère de recherche
d=input("Entrez le nom d'un pays : \n") #on demande à l'utilisateur son critère de recherche
e=input("Entrez le nom d'un acteur : \n") #on demande à l'utilisateur son critère de recherche

sortie4= ml.préférences_search(a, b, c, d, e)
print(sortie4) #on affiche les résultats
